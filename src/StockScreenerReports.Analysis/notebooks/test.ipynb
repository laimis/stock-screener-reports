# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)

# %%
data = pd.read_csv('test.csv', header=None)

# %%
data.sort_values(by=[0], inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#            0
# 0  -300.0000
# 1  -232.0000
# 2  -190.4400
# 3  -178.0863
# 4  -165.0000
# ..       ...
# 61  287.4000
# 62  342.6860
# 63  402.4700
# 64  525.9000
# 65  578.3995
#
# [66 rows x 1 columns]

# %%
data.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.sum()
# Out:
# 0    635.4074
# dtype: float64

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'0'}>]], dtype=object)

# %%
# histogram with two buckets: negative and positive
data.hist(bins=[-500,0,500])
# Out:
# array([[<AxesSubplot:title={'center':'0'}>]], dtype=object)

# %%
len(data[data < 0].dropna())
# Out:
# 34

# %%
data[data < 0].sum()
# Out:
# 0   -3519.1401
# dtype: float64

# %%
data[data > 0].sum()
# Out:
# 0    4154.5475
# dtype: float64
