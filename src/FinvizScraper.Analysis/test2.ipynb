# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)

# %%
df = pd.read_csv('test2_stripped.csv', header=None)
df.head()
# Out:
#           0
# 0  11994.40
# 1  10641.22
# 2   7449.09
# 3   5883.75
# 4   3405.01

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.sum()
# Out:
# 0    46090.47
# dtype: float64

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'0'}>]], dtype=object)

# %%
len(df[df < 0].dropna())
# Out:
# 107

# %%
df[df < 0].sum()
# Out:
# 0   -41565.16
# dtype: float64

# %%
df[df > 0].sum()
# Out:
# 0    87655.63
# dtype: float64
