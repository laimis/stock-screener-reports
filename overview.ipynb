# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [20, 10]

# %%
df = pd.read_csv("..\..\Downloads\export_New Highs, 1.5x volume, _$10 (3).csv")
df.head()
# Out:
#                           date ticker                          name  \
# 0  2022-03-22T00:00:00.0000000    TCN       Tricon Residential Inc.
# 1  2022-03-22T00:00:00.0000000   UNVR         Univar Solutions Inc.
# 2  2022-03-22T00:00:00.0000000   LNTH       Lantheus Holdings, Inc.
# 3  2022-03-22T00:00:00.0000000   TRTN  Triton International Limited
# 4  2022-03-22T00:00:00.0000000   IRTC    iRhythm Technologies, Inc.
#
#             sector                        industry  country  marketCap  \
# 0      Real Estate            Real Estate Services   Canada        0.0
# 1  Basic Materials                       Chemicals      USA        0.0
# 2       Healthcare          Diagnostics & Research      USA        0.0
# 3      Industrials       Rental & Leasing Services  Bermuda        0.0
# 4       Healthcare  Medical Instruments & Supplies      USA        0.0
#
#     price  change  volume
# 0   17.01     0.0       0
# 1   33.78     0.0       0
# 2   55.69     0.0       0
# 3   71.41     0.0       0
# 4  145.47     0.0       0

# %%
df['date'] = pd.to_datetime(df['date'])
df.drop(df[df["marketCap"] == 0].index, inplace=True)

# %%
df.head()
# Out:
#           date ticker                                               name  \
# 98  2022-04-01   TECK                             Teck Resources Limited
# 99  2022-04-01    NEX                    NexTier Oilfield Solutions Inc.
# 100 2022-04-01    SBS  Companhia de Saneamento Basico do Estado de Sa...
# 101 2022-04-01   ARLP                   Alliance Resource Partners, L.P.
# 102 2022-04-01   GLNG                                  Golar LNG Limited
#
#               sector                          industry  country     marketCap  \
# 98   Basic Materials  Other Industrial Metals & Mining   Canada  2.176000e+10
# 99            Energy    Oil & Gas Equipment & Services      USA  2.250000e+09
# 100        Utilities       Utilities - Regulated Water   Brazil  6.840000e+09
# 101           Energy                      Thermal Coal      USA  1.950000e+09
# 102           Energy               Oil & Gas Midstream  Bermuda  2.460000e+09
#
#      price  change   volume
# 98   42.15    4.35  4621608
# 99   10.07    9.04  2926285
# 100  10.56    7.43  2849200
# 101  15.49    0.42  1493801
# 102  25.29    2.06  1306556

# %%
groupedByTicker = df.groupby("ticker")

df["number_of_appearances"] = groupedByTicker["date"].transform("count")
df["max_price"] = groupedByTicker["price"].transform("max")
df["min_price"] = groupedByTicker["price"].transform("min")
df["earliest_date"] = groupedByTicker["date"].transform("min")
df["latest_date"] = groupedByTicker["date"].transform("max")
df["price_change"] = (df["max_price"] - df["min_price"]) / df["min_price"]

new_highs_with_p_clean = df[df["price_change"] > 0].groupby("ticker").first()

# %%
print("number of tickers with all time highs: ",len(df["ticker"].unique()))
print("number of winning tickers: ", len(new_highs_with_p_clean.index))


win_rate = len(new_highs_with_p_clean.index) / len(df["ticker"].unique())

print("Win rate: ", round(win_rate * 100, 2), "%")

reward = new_highs_with_p_clean["price_change"].median()
risk = 0.05

print("Reward: ", reward)
print("Risk: ", risk)
print("R:R = ", round(reward / risk, 2))

position_size = 3000

# expected value
ev = position_size * reward * win_rate - position_size * risk * (1 - win_rate)
print("EV: ", round(ev, 2))
# Out:
# number of tickers with all time highs:  183
# number of winning tickers:  72
# Win rate:  39.34 %
# Reward:  0.05441348433777223
# Risk:  0.05
# R:R =  1.09
# EV:  -26.76

# %%
new_highs_with_p_clean.groupby("industry")["price_change"].median().sort_values().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='industry'>

# %%
new_highs_with_p_clean[new_highs_with_p_clean["industry"] == "Coking Coal"]
# Out:
#              date                                 name           sector  \
# ticker
# AMR    2022-04-12  Alpha Metallurgical Resources, Inc.  Basic Materials
#
#            industry country     marketCap   price  change   volume  \
# ticker
# AMR     Coking Coal     USA  2.550000e+09  142.08   10.11  1077969
#
#         number_of_appearances  max_price  min_price earliest_date latest_date  \
# ticker
# AMR                         3     165.54     142.08    2022-04-12  2022-05-05
#
#         price_change
# ticker
# AMR         0.165118

# %%
new_highs_with_p_clean.boxplot(column="price_change", by="sector")
# Out:
# <AxesSubplot:title={'center':'price_change'}, xlabel='sector'>
